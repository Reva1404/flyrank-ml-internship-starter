# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# SEO Content Prioritization. I chose this lane because it combines machine learning with a real business problem. Instead of only predicting values, the goal is to help identify which web pages should be prioritized for optimization based on their potential impact. It offers a practical way to apply data analysis and predictive modeling while working on a problem that directly supports content strategy and search performance

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# This work improves the decision of which web pages should be prioritized for SEO optimization. The recommendations are used by SEO specialists and content managers to plan their optimization efforts. Incorrect recommendations can waste time and resources by focusing on low-impact pages while missing opportunities to increase traffic and business growth.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os
if not os.path.exists("data/raw/content_refresh_anonymized.csv"):
    # !git clone https://github.com/Reva1404/flyrank-ml-internship-starter
    os.chdir("flyrank-ml-internship-starter")

# %%
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print(df.shape)
df["trend_direction"].value_counts()
# Out:
# (30000, 44)
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This work provides decision-support by identifying patterns in historical SEO data and estimating which pages are more likely to benefit from optimization. The findings are directional rather than definitive and are intended to assist, not replace, human judgment. It does not establish causal relationships or predict Google's ranking algorithm or future search results with certainty.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
